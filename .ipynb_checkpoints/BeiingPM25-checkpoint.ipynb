# %%
import pandas as pd

df =pd.read_csv("data.csv")
df.head(15)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-07-02  183.820007  187.300003  183.419998  187.179993  182.199005
# 1   2018-07-03  187.789993  187.949997  183.539993  183.919998  179.025772
# 2   2018-07-05  185.259995  186.410004  184.279999  185.399994  180.466370
# 3   2018-07-06  185.419998  188.429993  185.199997  187.970001  182.967972
# 4   2018-07-09  189.500000  190.679993  189.300003  190.580002  185.508545
# 5   2018-07-10  190.710007  191.279999  190.179993  190.350006  185.284698
# 6   2018-07-11  188.500000  189.779999  187.610001  187.880005  182.880386
# 7   2018-07-12  189.529999  191.410004  189.309998  191.029999  185.946564
# 8   2018-07-13  191.080002  191.839996  190.899994  191.330002  186.238571
# 9   2018-07-16  191.520004  192.649994  190.419998  190.910004  185.829773
# 10  2018-07-17  189.750000  191.869995  189.199997  191.449997  186.355377
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       503 non-null    object
#  1   Open       503 non-null    float64
#  2   High       503 non-null    float64
#  3   Low        503 non-null    float64
#  4   Close      503 non-null    float64
#  5   Adj Close  503 non-null    float64
#  6   Volume     503 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 27.6+ KB

# %%
df.shape,len(df),len(df.columns)
# Out:
# ((503, 7), 503, 7)

# %%
df1 = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv")
df1.head(15)
# Out:
#     No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0    1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1    2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2    3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3    4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4    5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5    6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6    7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7    8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8    9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9   10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
# 10  11  2013      3    1    10    3.0   6.0   9.0  12.0  400.0  72.0   1.9
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
df1.shape
# Out:
# (35064, 18)

# %%
df1.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
df[df.isna().any(axis=1)],df1.isna().mean()
# Out:
# (Empty DataFrame
#  Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
#  Index: [],
#  No         0.000000
#  year       0.000000
#  month      0.000000
#  day        0.000000
#  hour       0.000000
#  PM2.5      0.026380
#  PM10       0.020477
#  SO2        0.026666
#  NO2        0.029175
#  CO         0.050650
#  O3         0.049025
#  TEMP       0.000570
#  PRES       0.000570
#  DEWP       0.000570
#  RAIN       0.000570
#  wd         0.002310
#  WSPM       0.000399
#  station    0.000000
#  dtype: float64)

# %%
df1.describe().T
# Out:
#          count          mean           std        min      25%      50%  \
# No     35064.0  17532.500000  10122.249256     1.0000  8766.75  17532.5
# year   35064.0   2014.662560      1.177213  2013.0000  2014.00   2015.0
# month  35064.0      6.522930      3.448752     1.0000     4.00      7.0
# day    35064.0     15.729637      8.800218     1.0000     8.00     16.0
# hour   35064.0     11.500000      6.922285     0.0000     5.75     11.5
# PM2.5  34139.0     82.773611     82.135694     3.0000    22.00     58.0
# PM10   34346.0    110.060391     95.223005     2.0000    38.00     87.0
# SO2    34129.0     17.375901     22.823017     0.2856     3.00      9.0
# NO2    34041.0     59.305833     37.116200     2.0000    30.00     53.0
# CO     33288.0   1262.945145   1221.436236   100.0000   500.00    900.0
# O3     33345.0     56.353358     57.916327     0.2142     8.00     42.0
# TEMP   35044.0     13.584607     11.399097   -16.8000     3.10     14.5
# ...

# %%
missing_df=df1[df1.isna().any(axis=1)]
missing_df
# Out:
#           No  year  month  day  hour  PM2.5   PM10      SO2       NO2      CO  \
# 74        75  2013      3    4     2   34.0   62.0      NaN   14.0000   300.0
# 75        76  2013      3    4     3   12.0   34.0   6.0000   12.0000     NaN
# 76        77  2013      3    4     4    7.0   18.0  14.0000       NaN   400.0
# 124      125  2013      3    6     4  192.0  203.0  83.6808  140.4252     NaN
# 170      171  2013      3    8     2  339.0  400.0      NaN  162.0000  3899.0
# ...      ...   ...    ...  ...   ...    ...    ...      ...       ...     ...
# 34912  34913  2017      2   22    16  131.0  131.0      NaN   95.0000     NaN
# 34913  34914  2017      2   22    17   28.0   28.0  11.0000   17.0000   500.0
# 35027  35028  2017      2   27    11  122.0  122.0      NaN       NaN     NaN
# 35028  35029  2017      2   27    12    NaN    NaN      NaN       NaN     NaN
# 35029  35030  2017      2   27    13    NaN    NaN      NaN       NaN     NaN
#
# ...

# %%
df1=df1.fillna(0)
